# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali4831/Ali4831/blob/main/Dr.AS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
import math

# %%
df = pd.read_csv('dep_clean.csv')

# %%
plt.subplots(figsize=(9, 9))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x = df.drop("dep", axis=1)
y = df.dep

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = Sequential()
model.add(Dense(64, input_dim=11, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='sigmoid'))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
 optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=( X_test, y_test), epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 32/32 [==============================] - 1s 11ms/step - loss: 1.3798 - accuracy: 0.4577 - val_loss: 0.9222 - val_accuracy: 0.6375
# Epoch 2/200
# 25/32 [======================>.......] - ETA: 0s - loss: 0.9058 - accuracy: 0.6480
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8942 - accuracy: 0.6426 - val_loss: 0.8709 - val_accuracy: 0.6625
# Epoch 3/200
# ...

# %%
scores = model.evaluate(X_train, y_train)
print("Training Accuracy: %.2f%%\n" % (scores[1]*100))
scores = model.evaluate(X_test, y_test)
print("Testing Accuracy: %.2f%%\n" % (scores[1]*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1135 - accuracy: 0.9561
# Training Accuracy: 95.61%
#
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3604 - accuracy: 0.9000
# Testing Accuracy: 90.00%

# %%
man = np.array([[1,3,3,33,0,0,2,1,2,2,2]])

# %%
out=model.predict(man)
h=np.array(out[0])
bars = ('low', 'medium', 'high')
# Out:
# 1/1 [==============================] - 0s 232ms/step

# %%
plt.bar(bars, h)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.show()
