# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali4831/Ali4831/blob/main/Welcome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sns.countplot(x='Outcome', data=df)
print('Number of Outcome for each 0 and 1 are:\n',
      df['Outcome'].value_counts())
# Out:
# Number of Outcome for each 0 and 1 are:
#  0    262
# 1    130
# Name: Outcome, dtype: int64

# %%
plt.subplots(figsize=(9, 9))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x = df.drop("Outcome", axis=1)
y = df.Outcome

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(
    X_test, y_test), epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 4s 26ms/step - loss: 1.0269 - accuracy: 0.6486 - val_loss: 0.7752 - val_accuracy: 0.6203
# Epoch 2/200
# 32/32 [==============================] - 0s 7ms/step - loss: 0.7879 - accuracy: 0.6134 - val_loss: 0.7336 - val_accuracy: 0.6456
# Epoch 3/200
# 32/32 [==============================] - 0s 8ms/step - loss: 0.7282 - accuracy: 0.6390 - val_loss: 0.7250 - val_accuracy: 0.6456
# Epoch 4/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7071 - accuracy: 0.6550 - val_loss: 0.7219 - val_accuracy: 0.6203
# Epoch 5/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6840 - accuracy: 0.6613 - val_loss: 0.7281 - val_accuracy: 0.6203
# Epoch 6/200
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6840 - accuracy: 0.6518 - val_loss: 0.6468 - val_accuracy: 0.6329
# Epoch 7/200
# ...

# %%
scores = model.evaluate(X_train, y_train)
print("Training Accuracy: %.2f%%\n" % (scores[1]*100))
scores = model.evaluate(X_test, y_test)
print("Testing Accuracy: %.2f%%\n" % (scores[1]*100))
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4834 - accuracy: 0.7732
# Training Accuracy: 77.32%
#
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6594 - accuracy: 0.6962
# Testing Accuracy: 69.62%

# %%
man = np.array([[0, 350, 100, 50, 100, 32, 2, 56]])
out1 = model.predict(man)
# Out:
# 1/1 [==============================] - 0s 386ms/step

# %%
print(out1)
# Out:
# [[0.9655505]]
